# %%
import rnn_cells
from rnn import dynamic_rnn
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
num_epochs = 100
total_series_length = 50000
max_time_steps = 10
state_size = 10
num_classes = 2
echo_step = 3
batch_size = 5
num_batches = total_series_length//max_time_steps//batch_size

# %%
def generate_data():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1, 1))
    y = y.reshape((batch_size, -1, 1))

    return (x, y)

# %%
batchX = tf.placeholder(tf.float32, [batch_size, max_time_steps, 1], name="X")
batchY = tf.placeholder(tf.int32, [batch_size, max_time_steps, 1], name="Y")

inputs_series = tf.unstack(batchX, axis=1)
labels_series = tf.unstack(tf.reshape(batchY,[batch_size, max_time_steps]), axis=1)

# %%
W_class = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b_class = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# %%
lstm_cell = rnn_cells.LSTMCell(state_size, input_size=1)

# %%
init_cell_state = tf.placeholder(tf.float32, [batch_size, state_size])
init_hidden_state = tf.placeholder(tf.float32, [batch_size, state_size])
initial_state = (init_cell_state, init_hidden_state)
output_states, final_state = dynamic_rnn(lstm_cell, batchX, initial_state=initial_state, dtype=tf.float32)

# %%
logits_series = [tf.matmul(state, W_class) + b_class for state in output_states]
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels) 
          for logits, labels in zip(logits_series, labels_series)]
total_loss = tf.reduce_mean(losses)

# %%
print labels_series[0]
print logits_series[0]
# Out:
# Tensor("unstack_1:0", shape=(5,), dtype=int32)
# Tensor("add:0", shape=(5, 2), dtype=float32)

# %%
train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    loss_list = []
    
    _cell_state = np.zeros([batch_size, state_size], dtype=np.float32)
    _hidden_state = np.zeros([batch_size, state_size], dtype=np.float32)
    _state = (_cell_state, _hidden_state)
    
    for epoch_idx in range(num_epochs):
        x, y = generate_data()
        
        print("New data, epoch", epoch_idx)
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * max_time_steps
            end_idx = start_idx + max_time_steps
            
            _batchX = x[:,start_idx:end_idx,:]
            _batchY = y[:,start_idx:end_idx]
            
            _total_loss, _train_step, _state, _predictions_series = sess.run(
                [total_loss, train_step, initial_state, predictions_series],
                feed_dict={
                    batchX: _batchX,
                    batchY: _batchY,
                    initial_state: _state
                })

            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Loss", _total_loss)
# Out:
# ('New data, epoch', 0)
# ('Step', 0, 'Loss', 0.74724555)
# ('Step', 100, 'Loss', 0.6117664)
# ('Step', 200, 'Loss', 0.3784672)
# ('Step', 300, 'Loss', 0.24713343)
# ('Step', 400, 'Loss', 0.23487505)
# ('Step', 500, 'Loss', 0.21619901)
# ('Step', 600, 'Loss', 0.24305928)
# ('Step', 700, 'Loss', 0.19282819)
# ('Step', 800, 'Loss', 0.24289352)
# ('Step', 900, 'Loss', 0.21515656)
# ('New data, epoch', 1)
# ('Step', 0, 'Loss', 0.22615322)
# ('Step', 100, 'Loss', 0.18510377)
# ('Step', 200, 'Loss', 0.22237438)
# ('Step', 300, 'Loss', 0.21045233)
# ('Step', 400, 'Loss', 0.19415361)
# ('Step', 500, 'Loss', 0.205651)
# ('Step', 600, 'Loss', 0.22585781)
# ('Step', 700, 'Loss', 0.23508471)
# ('Step', 800, 'Loss', 0.27521381)
# ('Step', 900, 'Loss', 0.1776036)
# ('New data, epoch', 2)
# ('Step', 0, 'Loss', 0.20564742)
# ('Step', 100, 'Loss', 0.20453459)
# ('Step', 200, 'Loss', 0.22780757)
# ('Step', 300, 'Loss', 0.20777182)
# ('Step', 400, 'Loss', 0.208685)
# ('Step', 500, 'Loss', 0.19484146)
# ('Step', 600, 'Loss', 0.22363579)
# ('Step', 700, 'Loss', 0.21113916)
# ('Step', 800, 'Loss', 0.21654211)
# ('Step', 900, 'Loss', 0.20478214)
# ('New data, epoch', 3)
# ('Step', 0, 'Loss', 0.19643293)
# ('Step', 100, 'Loss', 0.19762655)
# ('Step', 200, 'Loss', 0.20747776)
# ('Step', 300, 'Loss', 0.21787883)
# ('Step', 400, 'Loss', 0.1956858)
# ('Step', 500, 'Loss', 0.21586896)
# ('Step', 600, 'Loss', 0.19760336)
# ('Step', 700, 'Loss', 0.20193142)
# ('Step', 800, 'Loss', 0.20775084)
# ('Step', 900, 'Loss', 0.21235965)
# ('New data, epoch', 4)
# ('Step', 0, 'Loss', 0.19607331)
# ('Step', 100, 'Loss', 0.21044259)
# ('Step', 200, 'Loss', 0.20793031)
# ('Step', 300, 'Loss', 0.21223268)
# ('Step', 400, 'Loss', 0.19793138)
# ('Step', 500, 'Loss', 0.21465749)
# ('Step', 600, 'Loss', 0.20515658)
# ('Step', 700, 'Loss', 0.20437175)
# ('Step', 800, 'Loss', 0.2084967)
# ('Step', 900, 'Loss', 0.20697773)
# ('New data, epoch', 5)
# ('Step', 0, 'Loss', 0.22060825)
# ('Step', 100, 'Loss', 0.21756151)
# ('Step', 200, 'Loss', 0.20312786)
# ('Step', 300, 'Loss', 0.20382014)
# ('Step', 400, 'Loss', 0.19640049)
# ('Step', 500, 'Loss', 0.1883878)
# ('Step', 600, 'Loss', 0.21124424)
# ('Step', 700, 'Loss', 0.20565705)
# ('Step', 800, 'Loss', 0.21011423)
# ('Step', 900, 'Loss', 0.20452614)
# ('New data, epoch', 6)
# ('Step', 0, 'Loss', 0.210849)
# ('Step', 100, 'Loss', 0.20265223)
# ('Step', 200, 'Loss', 0.20339318)
# ('Step', 300, 'Loss', 0.19170114)
# ('Step', 400, 'Loss', 0.20010825)
# ('Step', 500, 'Loss', 0.21127395)
# ('Step', 600, 'Loss', 0.22521757)
# ('Step', 700, 'Loss', 0.21120162)
# ('Step', 800, 'Loss', 0.2077343)
# ('Step', 900, 'Loss', 0.2174243)
# ('New data, epoch', 7)
# ('Step', 0, 'Loss', 0.20500927)
# ('Step', 100, 'Loss', 0.19986069)
# ('Step', 200, 'Loss', 0.20940244)
# ('Step', 300, 'Loss', 0.21730435)
# ('Step', 400, 'Loss', 0.19792576)
# ('Step', 500, 'Loss', 0.20726672)
# ('Step', 600, 'Loss', 0.20243455)
# ('Step', 700, 'Loss', 0.22647496)
# ('Step', 800, 'Loss', 0.20359498)
# ('Step', 900, 'Loss', 0.21590397)
# ('New data, epoch', 8)
# ('Step', 0, 'Loss', 0.2112783)
# ('Step', 100, 'Loss', 0.21115366)
# ('Step', 200, 'Loss', 0.21315771)
# ('Step', 300, 'Loss', 0.21501936)
# ('Step', 400, 'Loss', 0.22247368)
# ('Step', 500, 'Loss', 0.2083275)
# ('Step', 600, 'Loss', 0.20428418)
# ('Step', 700, 'Loss', 0.21023603)
# ('Step', 800, 'Loss', 0.20778613)
# ('Step', 900, 'Loss', 0.21575131)
# ('New data, epoch', 9)
# ('Step', 0, 'Loss', 0.20604053)
# ('Step', 100, 'Loss', 0.21064785)
# ('Step', 200, 'Loss', 0.2116521)
# ('Step', 300, 'Loss', 0.20113419)
# ('Step', 400, 'Loss', 0.21400733)
# ('Step', 500, 'Loss', 0.20612949)
# ('Step', 600, 'Loss', 0.21132763)
# ('Step', 700, 'Loss', 0.21519867)
# ('Step', 800, 'Loss', 0.19825819)
# ('Step', 900, 'Loss', 0.21464977)
# ('New data, epoch', 10)
# ('Step', 0, 'Loss', 0.20589224)
# ('Step', 100, 'Loss', 0.21522214)
# ('Step', 200, 'Loss', 0.20426971)
# ('Step', 300, 'Loss', 0.21461955)
# ('Step', 400, 'Loss', 0.21393134)
# ('Step', 500, 'Loss', 0.20093575)
# ('Step', 600, 'Loss', 0.2122689)
# ('Step', 700, 'Loss', 0.2071171)
# ('Step', 800, 'Loss', 0.21008436)
# ('Step', 900, 'Loss', 0.20579392)
# ('New data, epoch', 11)
# ('Step', 0, 'Loss', 0.20780689)
# ('Step', 100, 'Loss', 0.21265854)
# ('Step', 200, 'Loss', 0.20654896)
# ('Step', 300, 'Loss', 0.21271223)
# ('Step', 400, 'Loss', 0.21829124)
# ('Step', 500, 'Loss', 0.20685679)
# ('Step', 600, 'Loss', 0.20981646)
# ('Step', 700, 'Loss', 0.18844759)
# ('Step', 800, 'Loss', 0.21676581)
# ('Step', 900, 'Loss', 0.21661259)
# ('New data, epoch', 12)
# ('Step', 0, 'Loss', 0.22256102)
# ('Step', 100, 'Loss', 0.21951555)
# ('Step', 200, 'Loss', 0.20591441)
# ('Step', 300, 'Loss', 0.21883862)
# ('Step', 400, 'Loss', 0.20761061)
# ('Step', 500, 'Loss', 0.20988525)
# ('Step', 600, 'Loss', 0.20232287)
# ('Step', 700, 'Loss', 0.20978118)
# ('Step', 800, 'Loss', 0.21288747)
# ('Step', 900, 'Loss', 0.21059117)
# ('New data, epoch', 13)
# ('Step', 0, 'Loss', 0.19468334)
# ('Step', 100, 'Loss', 0.20586905)
# ('Step', 200, 'Loss', 0.21127069)
# ('Step', 300, 'Loss', 0.20573296)
# ('Step', 400, 'Loss', 0.22140156)
# ('Step', 500, 'Loss', 0.20533744)
# ('Step', 600, 'Loss', 0.21786755)
# ('Step', 700, 'Loss', 0.20662396)
# ('Step', 800, 'Loss', 0.20856321)
# ('Step', 900, 'Loss', 0.20811667)
# ('New data, epoch', 14)
# ('Step', 0, 'Loss', 0.21191034)
# ('Step', 100, 'Loss', 0.20416485)
# ('Step', 200, 'Loss', 0.21049307)
# ('Step', 300, 'Loss', 0.2037915)
# ('Step', 400, 'Loss', 0.20811935)
# ('Step', 500, 'Loss', 0.21549408)
# ('Step', 600, 'Loss', 0.21301104)
# ('Step', 700, 'Loss', 0.20655276)
# ('Step', 800, 'Loss', 0.21355501)
# ('Step', 900, 'Loss', 0.20442539)
# ('New data, epoch', 15)
# ('Step', 0, 'Loss', 0.21181384)
# ('Step', 100, 'Loss', 0.18995744)
# ('Step', 200, 'Loss', 0.20680207)
# ('Step', 300, 'Loss', 0.22310549)
# ('Step', 400, 'Loss', 0.19666331)
# ('Step', 500, 'Loss', 0.21626818)
# ('Step', 600, 'Loss', 0.20769912)
# ('Step', 700, 'Loss', 0.21409272)
# ('Step', 800, 'Loss', 0.21206558)
# ('Step', 900, 'Loss', 0.20767941)
# ('New data, epoch', 16)
# ('Step', 0, 'Loss', 0.21555527)
# ('Step', 100, 'Loss', 0.20676035)
# ('Step', 200, 'Loss', 0.21339273)
# ('Step', 300, 'Loss', 0.20652603)
# ('Step', 400, 'Loss', 0.2043968)
# ('Step', 500, 'Loss', 0.20365292)
# ('Step', 600, 'Loss', 0.22209685)
# ('Step', 700, 'Loss', 0.21087301)
# ('Step', 800, 'Loss', 0.20799255)
# ('Step', 900, 'Loss', 0.20782064)
# ('New data, epoch', 17)
# ('Step', 0, 'Loss', 0.2120358)
# ('Step', 100, 'Loss', 0.20695865)
# ('Step', 200, 'Loss', 0.20719196)
# ('Step', 300, 'Loss', 0.21363686)
# ('Step', 400, 'Loss', 0.20062681)
# ('Step', 500, 'Loss', 0.21386622)
# ('Step', 600, 'Loss', 0.20868379)
# ('Step', 700, 'Loss', 0.20759362)
# ('Step', 800, 'Loss', 0.20716022)
# ('Step', 900, 'Loss', 0.21366666)
# ('New data, epoch', 18)
# ('Step', 0, 'Loss', 0.19988739)
# ('Step', 100, 'Loss', 0.20365156)
# ('Step', 200, 'Loss', 0.20678034)
# ('Step', 300, 'Loss', 0.21620886)
# ('Step', 400, 'Loss', 0.20824717)
# ('Step', 500, 'Loss', 0.22779123)
# ('Step', 600, 'Loss', 0.20632274)
# ('Step', 700, 'Loss', 0.21720177)
# ('Step', 800, 'Loss', 0.21435331)
# ('Step', 900, 'Loss', 0.21227562)
# ('New data, epoch', 19)
# ('Step', 0, 'Loss', 0.20542821)
# ('Step', 100, 'Loss', 0.21196781)
# ('Step', 200, 'Loss', 0.20652479)
# ('Step', 300, 'Loss', 0.22300868)
# ('Step', 400, 'Loss', 0.20120077)
# ('Step', 500, 'Loss', 0.21035911)
# ('Step', 600, 'Loss', 0.21067539)
# ('Step', 700, 'Loss', 0.20636618)
# ('Step', 800, 'Loss', 0.21113417)
# ('Step', 900, 'Loss', 0.22033781)
# ('New data, epoch', 20)
# ('Step', 0, 'Loss', 0.21208958)
# ('Step', 100, 'Loss', 0.21068512)
# ('Step', 200, 'Loss', 0.22259639)
# ('Step', 300, 'Loss', 0.21387722)
# ('Step', 400, 'Loss', 0.21106347)
# ('Step', 500, 'Loss', 0.21915171)
# ('Step', 600, 'Loss', 0.2008526)
# ('Step', 700, 'Loss', 0.21985061)
# ('Step', 800, 'Loss', 0.2022801)
# ('Step', 900, 'Loss', 0.20511629)
# ('New data, epoch', 21)
# ('Step', 0, 'Loss', 0.20363945)
# ('Step', 100, 'Loss', 0.21509516)
# ('Step', 200, 'Loss', 0.20595703)
# ('Step', 300, 'Loss', 0.20440175)
# ('Step', 400, 'Loss', 0.20916948)
# ('Step', 500, 'Loss', 0.20508005)
# ('Step', 600, 'Loss', 0.19786349)
# ('Step', 700, 'Loss', 0.20367514)
# ('Step', 800, 'Loss', 0.21284442)
# ('Step', 900, 'Loss', 0.2071557)
# ('New data, epoch', 22)
# ('Step', 0, 'Loss', 0.20710245)
# ('Step', 100, 'Loss', 0.20812178)
# ('Step', 200, 'Loss', 0.20950086)
# ('Step', 300, 'Loss', 0.21140955)
# ('Step', 400, 'Loss', 0.21235499)
# ('Step', 500, 'Loss', 0.21769258)
# ('Step', 600, 'Loss', 0.20883074)
# ('Step', 700, 'Loss', 0.19746619)
# ('Step', 800, 'Loss', 0.21132553)
# ('Step', 900, 'Loss', 0.20658045)
# ('New data, epoch', 23)
# ('Step', 0, 'Loss', 0.20973623)
# ('Step', 100, 'Loss', 0.21102639)
# ('Step', 200, 'Loss', 0.209539)
# ('Step', 300, 'Loss', 0.208103)
# ('Step', 400, 'Loss', 0.20687893)
# ('Step', 500, 'Loss', 0.20269209)
# ('Step', 600, 'Loss', 0.20401873)
# ('Step', 700, 'Loss', 0.20549235)
# ('Step', 800, 'Loss', 0.19663039)
# ('Step', 900, 'Loss', 0.21122558)
# ('New data, epoch', 24)
# ('Step', 0, 'Loss', 0.21345328)
# ('Step', 100, 'Loss', 0.20687634)
# ('Step', 200, 'Loss', 0.21581723)
# ('Step', 300, 'Loss', 0.21012922)
# ('Step', 400, 'Loss', 0.21118237)
# ('Step', 500, 'Loss', 0.20949073)
# ('Step', 600, 'Loss', 0.20573786)
# ('Step', 700, 'Loss', 0.20747207)
# ('Step', 800, 'Loss', 0.216536)
# ('Step', 900, 'Loss', 0.20243372)
# ('New data, epoch', 25)
# ('Step', 0, 'Loss', 0.21710312)
# ('Step', 100, 'Loss', 0.20868771)
# ('Step', 200, 'Loss', 0.20870104)
# ('Step', 300, 'Loss', 0.21373236)
# ('Step', 400, 'Loss', 0.21121091)
# ('Step', 500, 'Loss', 0.20976606)
# ('Step', 600, 'Loss', 0.21006095)
# ('Step', 700, 'Loss', 0.20546107)
# ('Step', 800, 'Loss', 0.21948367)
# ('Step', 900, 'Loss', 0.20968361)
# ('New data, epoch', 26)
# ('Step', 0, 'Loss', 0.20824203)
# ('Step', 100, 'Loss', 0.20090169)
# ('Step', 200, 'Loss', 0.20954448)
# ('Step', 300, 'Loss', 0.2136479)
# ('Step', 400, 'Loss', 0.21686549)
# ('Step', 500, 'Loss', 0.20162943)
# ('Step', 600, 'Loss', 0.20203486)
# ('Step', 700, 'Loss', 0.20654435)
# ('Step', 800, 'Loss', 0.20901281)
# ('Step', 900, 'Loss', 0.20790176)
# ('New data, epoch', 27)
# ('Step', 0, 'Loss', 0.2136526)
# ('Step', 100, 'Loss', 0.20785041)
# ('Step', 200, 'Loss', 0.19919367)
# ('Step', 300, 'Loss', 0.2145009)
# ('Step', 400, 'Loss', 0.20978315)
# ('Step', 500, 'Loss', 0.20015746)
# ('Step', 600, 'Loss', 0.20711148)
# ('Step', 700, 'Loss', 0.20588727)
# ('Step', 800, 'Loss', 0.20529802)
# ('Step', 900, 'Loss', 0.20903814)
# ('New data, epoch', 28)
# ('Step', 0, 'Loss', 0.2200512)
# ('Step', 100, 'Loss', 0.20500205)
# ('Step', 200, 'Loss', 0.20853314)
# ('Step', 300, 'Loss', 0.20656581)
# ('Step', 400, 'Loss', 0.20496505)
# ('Step', 500, 'Loss', 0.21538681)
# ('Step', 600, 'Loss', 0.21836899)
# ('Step', 700, 'Loss', 0.2041342)
# ('Step', 800, 'Loss', 0.19693628)
# ('Step', 900, 'Loss', 0.20246081)
# ('New data, epoch', 29)
# ('Step', 0, 'Loss', 0.21429199)
# ('Step', 100, 'Loss', 0.2075647)
# ('Step', 200, 'Loss', 0.20656687)
# ('Step', 300, 'Loss', 0.21469687)
# ('Step', 400, 'Loss', 0.20697619)
# ('Step', 500, 'Loss', 0.21051538)
# ('Step', 600, 'Loss', 0.21056917)
# ('Step', 700, 'Loss', 0.19801863)
# ('Step', 800, 'Loss', 0.20479803)
# ('Step', 900, 'Loss', 0.20997468)
# ('New data, epoch', 30)
# ('Step', 0, 'Loss', 0.21571971)
# ('Step', 100, 'Loss', 0.21632169)
# ('Step', 200, 'Loss', 0.20213827)
# ('Step', 300, 'Loss', 0.20919813)
# ('Step', 400, 'Loss', 0.21370609)
# ('Step', 500, 'Loss', 0.2069792)
# ('Step', 600, 'Loss', 0.21574168)
# ('Step', 700, 'Loss', 0.21555881)
# ('Step', 800, 'Loss', 0.21494852)
# ('Step', 900, 'Loss', 0.20433646)
# ('New data, epoch', 31)
# ('Step', 0, 'Loss', 0.20212261)
# ('Step', 100, 'Loss', 0.22056237)
# ('Step', 200, 'Loss', 0.20870939)
# ('Step', 300, 'Loss', 0.20887294)
# ('Step', 400, 'Loss', 0.21036734)
# ('Step', 500, 'Loss', 0.20937546)
# ('Step', 600, 'Loss', 0.21229446)
# ('Step', 700, 'Loss', 0.20611368)
# ('Step', 800, 'Loss', 0.20822625)
# ('Step', 900, 'Loss', 0.20970701)
# ('New data, epoch', 32)
# ('Step', 0, 'Loss', 0.20555466)
# ('Step', 100, 'Loss', 0.2055348)
# ('Step', 200, 'Loss', 0.20895208)
# ('Step', 300, 'Loss', 0.20814094)
# ('Step', 400, 'Loss', 0.20646143)
# ('Step', 500, 'Loss', 0.23290148)
# ('Step', 600, 'Loss', 0.20068169)
# ('Step', 700, 'Loss', 0.2060436)
# ('Step', 800, 'Loss', 0.20715345)
# ('Step', 900, 'Loss', 0.20142601)
# ('New data, epoch', 33)
# ('Step', 0, 'Loss', 0.20520627)
# ('Step', 100, 'Loss', 0.20528208)
# ('Step', 200, 'Loss', 0.20246956)
# ('Step', 300, 'Loss', 0.20978943)
# ('Step', 400, 'Loss', 0.20630822)
# ('Step', 500, 'Loss', 0.2051779)
# ('Step', 600, 'Loss', 0.2088059)
# ('Step', 700, 'Loss', 0.22193938)
# ('Step', 800, 'Loss', 0.2020146)
# ('Step', 900, 'Loss', 0.20069118)
# ('New data, epoch', 34)
# ('Step', 0, 'Loss', 0.21059896)
# ('Step', 100, 'Loss', 0.21271455)
# ('Step', 200, 'Loss', 0.20868145)
# ('Step', 300, 'Loss', 0.20599721)
# ('Step', 400, 'Loss', 0.21631573)
# ('Step', 500, 'Loss', 0.20445049)
# ('Step', 600, 'Loss', 0.20937876)
# ('Step', 700, 'Loss', 0.21351779)
# ('Step', 800, 'Loss', 0.21175508)
# ('Step', 900, 'Loss', 0.20170051)
# ('New data, epoch', 35)
# ('Step', 0, 'Loss', 0.20801781)
# ('Step', 100, 'Loss', 0.21229112)
# ('Step', 200, 'Loss', 0.21138981)
# ('Step', 300, 'Loss', 0.21531458)
# ('Step', 400, 'Loss', 0.21238083)
# ('Step', 500, 'Loss', 0.21451885)
# ('Step', 600, 'Loss', 0.20606782)
# ('Step', 700, 'Loss', 0.21233334)
# ('Step', 800, 'Loss', 0.20599513)
# ('Step', 900, 'Loss', 0.20277111)
# ('New data, epoch', 36)
# ('Step', 0, 'Loss', 0.20486332)
# ('Step', 100, 'Loss', 0.20589033)
# ('Step', 200, 'Loss', 0.21504259)
# ('Step', 300, 'Loss', 0.20016879)
# ('Step', 400, 'Loss', 0.20984378)
# ('Step', 500, 'Loss', 0.21736808)
# ('Step', 600, 'Loss', 0.21667372)
# ('Step', 700, 'Loss', 0.208556)
# ('Step', 800, 'Loss', 0.20243059)
# ('Step', 900, 'Loss', 0.21261732)
# ('New data, epoch', 37)
# ('Step', 0, 'Loss', 0.21034664)
# ('Step', 100, 'Loss', 0.2071117)
# ('Step', 200, 'Loss', 0.21093826)
# ('Step', 300, 'Loss', 0.21074812)
# ('Step', 400, 'Loss', 0.21087803)
# ('Step', 500, 'Loss', 0.21609588)
# ('Step', 600, 'Loss', 0.22423987)
# ('Step', 700, 'Loss', 0.2061519)
# ('Step', 800, 'Loss', 0.20582819)
# ('Step', 900, 'Loss', 0.20915224)
# ('New data, epoch', 38)
# ('Step', 0, 'Loss', 0.21701419)
# ('Step', 100, 'Loss', 0.22366627)
# ('Step', 200, 'Loss', 0.19762449)
# ('Step', 300, 'Loss', 0.20629033)
# ('Step', 400, 'Loss', 0.20476899)
# ('Step', 500, 'Loss', 0.20526432)
# ('Step', 600, 'Loss', 0.20419604)
# ('Step', 700, 'Loss', 0.20966385)
# ('Step', 800, 'Loss', 0.20190415)
# ('Step', 900, 'Loss', 0.20846094)
# ('New data, epoch', 39)
# ('Step', 0, 'Loss', 0.20745197)
# ('Step', 100, 'Loss', 0.21206766)
# ('Step', 200, 'Loss', 0.21079014)
# ('Step', 300, 'Loss', 0.21484743)
# ('Step', 400, 'Loss', 0.21793236)
# ('Step', 500, 'Loss', 0.21006727)
# ('Step', 600, 'Loss', 0.20304866)
# ('Step', 700, 'Loss', 0.21087612)
# ('Step', 800, 'Loss', 0.21002647)
# ('Step', 900, 'Loss', 0.21224551)
# ('New data, epoch', 40)
# ('Step', 0, 'Loss', 0.21074964)
# ('Step', 100, 'Loss', 0.20713192)
# ('Step', 200, 'Loss', 0.2104273)
# ('Step', 300, 'Loss', 0.20121521)
# ('Step', 400, 'Loss', 0.20555913)
# ('Step', 500, 'Loss', 0.2113501)
# ('Step', 600, 'Loss', 0.21288894)
# ('Step', 700, 'Loss', 0.20958433)
# ('Step', 800, 'Loss', 0.20500748)
# ('Step', 900, 'Loss', 0.20959778)
# ('New data, epoch', 41)
# ('Step', 0, 'Loss', 0.20780867)
# ('Step', 100, 'Loss', 0.20502263)
# ('Step', 200, 'Loss', 0.20242856)
# ('Step', 300, 'Loss', 0.19949207)
# ('Step', 400, 'Loss', 0.2073461)
# ('Step', 500, 'Loss', 0.20446295)
# ('Step', 600, 'Loss', 0.20737818)
# ('Step', 700, 'Loss', 0.21010044)
# ('Step', 800, 'Loss', 0.21035299)
# ('Step', 900, 'Loss', 0.20257577)
# ('New data, epoch', 42)
# ('Step', 0, 'Loss', 0.21624111)
# ('Step', 100, 'Loss', 0.20529856)
# ('Step', 200, 'Loss', 0.21240407)
# ('Step', 300, 'Loss', 0.20793147)
# ('Step', 400, 'Loss', 0.19671905)
# ('Step', 500, 'Loss', 0.21088982)
# ('Step', 600, 'Loss', 0.20872277)
# ('Step', 700, 'Loss', 0.20813042)
# ('Step', 800, 'Loss', 0.21117975)
# ('Step', 900, 'Loss', 0.21035242)
# ('New data, epoch', 43)
# ('Step', 0, 'Loss', 0.22510029)
# ('Step', 100, 'Loss', 0.20816594)
# ('Step', 200, 'Loss', 0.20978208)
# ('Step', 300, 'Loss', 0.20584074)
# ('Step', 400, 'Loss', 0.20781894)
# ('Step', 500, 'Loss', 0.20364614)
# ('Step', 600, 'Loss', 0.21624394)
# ('Step', 700, 'Loss', 0.20595585)
# ('Step', 800, 'Loss', 0.21094616)
# ('Step', 900, 'Loss', 0.21370602)
# ('New data, epoch', 44)
# ('Step', 0, 'Loss', 0.21048839)
# ('Step', 100, 'Loss', 0.20298404)
# ('Step', 200, 'Loss', 0.21229103)
# ('Step', 300, 'Loss', 0.2127268)
# ('Step', 400, 'Loss', 0.20555156)
# ('Step', 500, 'Loss', 0.20759073)
# ('Step', 600, 'Loss', 0.21378757)
# ('Step', 700, 'Loss', 0.20248391)
# ('Step', 800, 'Loss', 0.20840973)
# ('Step', 900, 'Loss', 0.20646641)
# ('New data, epoch', 45)
# ('Step', 0, 'Loss', 0.21090716)
# ('Step', 100, 'Loss', 0.19867329)
# ('Step', 200, 'Loss', 0.20979413)
# ('Step', 300, 'Loss', 0.20589292)
# ('Step', 400, 'Loss', 0.1956915)
# ('Step', 500, 'Loss', 0.2094093)
# ('Step', 600, 'Loss', 0.20708349)
# ('Step', 700, 'Loss', 0.20448755)
# ('Step', 800, 'Loss', 0.20354719)
# ('Step', 900, 'Loss', 0.21069324)
# ('New data, epoch', 46)
# ('Step', 0, 'Loss', 0.2123227)
# ('Step', 100, 'Loss', 0.21109529)
# ('Step', 200, 'Loss', 0.20627977)
# ('Step', 300, 'Loss', 0.20706205)
# ('Step', 400, 'Loss', 0.20906042)
# ('Step', 500, 'Loss', 0.20821744)
# ('Step', 600, 'Loss', 0.21604539)
# ('Step', 700, 'Loss', 0.21235579)
# ('Step', 800, 'Loss', 0.20458385)
# ('Step', 900, 'Loss', 0.2087865)
# ('New data, epoch', 47)
# ('Step', 0, 'Loss', 0.20553219)
# ('Step', 100, 'Loss', 0.20389067)
# ('Step', 200, 'Loss', 0.21220441)
# ('Step', 300, 'Loss', 0.20960306)
# ('Step', 400, 'Loss', 0.20760426)
# ('Step', 500, 'Loss', 0.20605822)
# ('Step', 600, 'Loss', 0.21095629)
# ('Step', 700, 'Loss', 0.20589045)
# ('Step', 800, 'Loss', 0.2061141)
# ('Step', 900, 'Loss', 0.2062639)
# ('New data, epoch', 48)
# ('Step', 0, 'Loss', 0.21371324)
# ('Step', 100, 'Loss', 0.20889468)
# ('Step', 200, 'Loss', 0.2069716)
# ('Step', 300, 'Loss', 0.19985083)
# ('Step', 400, 'Loss', 0.20939974)
# ('Step', 500, 'Loss', 0.20963174)
# ('Step', 600, 'Loss', 0.20781335)
# ('Step', 700, 'Loss', 0.2153496)
# ('Step', 800, 'Loss', 0.20963749)
# ('Step', 900, 'Loss', 0.20385048)
# ('New data, epoch', 49)
# ('Step', 0, 'Loss', 0.20499371)
# ('Step', 100, 'Loss', 0.20720196)
# ('Step', 200, 'Loss', 0.20723034)
# ('Step', 300, 'Loss', 0.20625494)
# ('Step', 400, 'Loss', 0.20386867)
# ('Step', 500, 'Loss', 0.21490778)
# ('Step', 600, 'Loss', 0.20937958)
# ('Step', 700, 'Loss', 0.21174008)
# ('Step', 800, 'Loss', 0.20353304)
# ('Step', 900, 'Loss', 0.21250078)
# ('New data, epoch', 50)
# ('Step', 0, 'Loss', 0.20707043)
# ('Step', 100, 'Loss', 0.20750085)
# ('Step', 200, 'Loss', 0.21184812)
# ('Step', 300, 'Loss', 0.2077533)
# ('Step', 400, 'Loss', 0.21128765)
# ('Step', 500, 'Loss', 0.20577221)
# ('Step', 600, 'Loss', 0.21180534)
# ('Step', 700, 'Loss', 0.20844376)
# ('Step', 800, 'Loss', 0.21861783)
# ('Step', 900, 'Loss', 0.20618105)
# ('New data, epoch', 51)
# ('Step', 0, 'Loss', 0.20051083)
# ('Step', 100, 'Loss', 0.21405311)
# ('Step', 200, 'Loss', 0.21162061)
# ('Step', 300, 'Loss', 0.20074223)
# ('Step', 400, 'Loss', 0.21045114)
# ('Step', 500, 'Loss', 0.20992449)
# ('Step', 600, 'Loss', 0.20699684)
# ('Step', 700, 'Loss', 0.20641683)
# ('Step', 800, 'Loss', 0.20988256)
# ('Step', 900, 'Loss', 0.20685568)
# ('New data, epoch', 52)
# ('Step', 0, 'Loss', 0.21945223)
# ('Step', 100, 'Loss', 0.21164984)
# ('Step', 200, 'Loss', 0.2132377)
# ('Step', 300, 'Loss', 0.21612042)
# ('Step', 400, 'Loss', 0.20451486)
# ('Step', 500, 'Loss', 0.20986435)
# ('Step', 600, 'Loss', 0.21415025)
# ('Step', 700, 'Loss', 0.21333225)
# ('Step', 800, 'Loss', 0.21779668)
# ('Step', 900, 'Loss', 0.2145105)
# ('New data, epoch', 53)
# ('Step', 0, 'Loss', 0.21204954)
# ('Step', 100, 'Loss', 0.21201853)
# ('Step', 200, 'Loss', 0.20390695)
# ('Step', 300, 'Loss', 0.20644827)
# ('Step', 400, 'Loss', 0.21125291)
# ('Step', 500, 'Loss', 0.20946018)
# ('Step', 600, 'Loss', 0.20237043)
# ('Step', 700, 'Loss', 0.2063264)
# ('Step', 800, 'Loss', 0.21224344)
# ('Step', 900, 'Loss', 0.20496315)
# ('New data, epoch', 54)
# ('Step', 0, 'Loss', 0.20119858)
# ('Step', 100, 'Loss', 0.21405756)
# ('Step', 200, 'Loss', 0.20749494)
# ('Step', 300, 'Loss', 0.20927005)
# ('Step', 400, 'Loss', 0.21037447)
# ('Step', 500, 'Loss', 0.21414411)
# ('Step', 600, 'Loss', 0.21069963)
# ('Step', 700, 'Loss', 0.20206477)
# ('Step', 800, 'Loss', 0.21180864)
# ('Step', 900, 'Loss', 0.20156357)
# ('New data, epoch', 55)
# ('Step', 0, 'Loss', 0.21162476)
# ('Step', 100, 'Loss', 0.20954508)
# ('Step', 200, 'Loss', 0.21482922)
# ('Step', 300, 'Loss', 0.20880513)
# ('Step', 400, 'Loss', 0.20836304)
# ('Step', 500, 'Loss', 0.21075505)
# ('Step', 600, 'Loss', 0.20118973)
# ('Step', 700, 'Loss', 0.20852084)
# ('Step', 800, 'Loss', 0.20334408)
# ('Step', 900, 'Loss', 0.20511988)
# ('New data, epoch', 56)
# ('Step', 0, 'Loss', 0.21029609)
# ('Step', 100, 'Loss', 0.21318224)
# ('Step', 200, 'Loss', 0.20307499)
# ('Step', 300, 'Loss', 0.21391936)
# ('Step', 400, 'Loss', 0.21306977)
# ('Step', 500, 'Loss', 0.20528576)
# ('Step', 600, 'Loss', 0.21499616)
# ('Step', 700, 'Loss', 0.20654505)
# ('Step', 800, 'Loss', 0.21612044)
# ('Step', 900, 'Loss', 0.21369761)
# ('New data, epoch', 57)
# ('Step', 0, 'Loss', 0.20912765)
# ('Step', 100, 'Loss', 0.21043465)
# ('Step', 200, 'Loss', 0.20584331)
# ('Step', 300, 'Loss', 0.20944816)
# ('Step', 400, 'Loss', 0.21042192)
# ('Step', 500, 'Loss', 0.20881575)
# ('Step', 600, 'Loss', 0.20510074)
# ('Step', 700, 'Loss', 0.19796827)
# ('Step', 800, 'Loss', 0.21312718)
# ('Step', 900, 'Loss', 0.21326692)
# ('New data, epoch', 58)
# ('Step', 0, 'Loss', 0.19691414)
# ('Step', 100, 'Loss', 0.20050085)
# ('Step', 200, 'Loss', 0.21315236)
# ('Step', 300, 'Loss', 0.2086412)
# ('Step', 400, 'Loss', 0.20566502)
# ('Step', 500, 'Loss', 0.20877084)
# ('Step', 600, 'Loss', 0.20879085)
# ('Step', 700, 'Loss', 0.20943438)
# ('Step', 800, 'Loss', 0.21249355)
# ('Step', 900, 'Loss', 0.20681515)
# ('New data, epoch', 59)
# ('Step', 0, 'Loss', 0.21057716)
# ('Step', 100, 'Loss', 0.21405907)
# ('Step', 200, 'Loss', 0.21236183)
# ('Step', 300, 'Loss', 0.20652586)
# ('Step', 400, 'Loss', 0.2042643)
# ('Step', 500, 'Loss', 0.20602731)
# ('Step', 600, 'Loss', 0.2066638)
# ('Step', 700, 'Loss', 0.2048312)
# ('Step', 800, 'Loss', 0.20548689)
# ('Step', 900, 'Loss', 0.20958006)
# ('New data, epoch', 60)
# ('Step', 0, 'Loss', 0.21033572)
# ('Step', 100, 'Loss', 0.21094042)
# ('Step', 200, 'Loss', 0.21143463)
# ('Step', 300, 'Loss', 0.21374436)
# ('Step', 400, 'Loss', 0.20646924)
# ('Step', 500, 'Loss', 0.2016425)
# ('Step', 600, 'Loss', 0.20294073)
# ('Step', 700, 'Loss', 0.21622111)
# ('Step', 800, 'Loss', 0.20852557)
# ('Step', 900, 'Loss', 0.20693555)
# ('New data, epoch', 61)
# ('Step', 0, 'Loss', 0.20245905)
# ('Step', 100, 'Loss', 0.20966816)
# ('Step', 200, 'Loss', 0.19907606)
# ('Step', 300, 'Loss', 0.2040468)
# ('Step', 400, 'Loss', 0.20627233)
# ('Step', 500, 'Loss', 0.20827667)
# ('Step', 600, 'Loss', 0.21360311)
# ('Step', 700, 'Loss', 0.20433231)
# ('Step', 800, 'Loss', 0.21351551)
# ('Step', 900, 'Loss', 0.20930867)
# ('New data, epoch', 62)
# ('Step', 0, 'Loss', 0.20565344)
# ('Step', 100, 'Loss', 0.21836142)
# ('Step', 200, 'Loss', 0.20393118)
# ('Step', 300, 'Loss', 0.20663179)
# ('Step', 400, 'Loss', 0.20383687)
# ('Step', 500, 'Loss', 0.20385502)
# ('Step', 600, 'Loss', 0.20900865)
# ('Step', 700, 'Loss', 0.21404333)
# ('Step', 800, 'Loss', 0.20511764)
# ('Step', 900, 'Loss', 0.2118306)
# ('New data, epoch', 63)
# ('Step', 0, 'Loss', 0.20989835)
# ('Step', 100, 'Loss', 0.20836462)
# ('Step', 200, 'Loss', 0.21125226)
# ('Step', 300, 'Loss', 0.20637178)
# ('Step', 400, 'Loss', 0.21233462)
# ('Step', 500, 'Loss', 0.2133151)
# ('Step', 600, 'Loss', 0.2088397)
# ('Step', 700, 'Loss', 0.20489237)
# ('Step', 800, 'Loss', 0.2086817)
# ('Step', 900, 'Loss', 0.2174478)
# ('New data, epoch', 64)
# ('Step', 0, 'Loss', 0.20218426)
# ('Step', 100, 'Loss', 0.20692511)
# ('Step', 200, 'Loss', 0.21114056)
# ('Step', 300, 'Loss', 0.20436473)
# ('Step', 400, 'Loss', 0.20939104)
# ('Step', 500, 'Loss', 0.2041903)
# ('Step', 600, 'Loss', 0.21188645)
# ('Step', 700, 'Loss', 0.20694603)
# ('Step', 800, 'Loss', 0.20449188)
# ('Step', 900, 'Loss', 0.21296383)
# ('New data, epoch', 65)
# ('Step', 0, 'Loss', 0.20833594)
# ('Step', 100, 'Loss', 0.20857908)
# ('Step', 200, 'Loss', 0.20514639)
# ('Step', 300, 'Loss', 0.20884117)
# ('Step', 400, 'Loss', 0.20601921)
# ('Step', 500, 'Loss', 0.20999962)
# ('Step', 600, 'Loss', 0.20621699)
# ('Step', 700, 'Loss', 0.20881474)
# ('Step', 800, 'Loss', 0.20217514)
# ('Step', 900, 'Loss', 0.20211139)
# ('New data, epoch', 66)
# ('Step', 0, 'Loss', 0.20865726)
# ('Step', 100, 'Loss', 0.2073728)
# ('Step', 200, 'Loss', 0.20410742)
# ('Step', 300, 'Loss', 0.21133429)
# ('Step', 400, 'Loss', 0.21117701)
# ('Step', 500, 'Loss', 0.21145085)
# ('Step', 600, 'Loss', 0.20927627)
# ('Step', 700, 'Loss', 0.20666938)
# ('Step', 800, 'Loss', 0.21361379)
# ('Step', 900, 'Loss', 0.20326899)
# ('New data, epoch', 67)
# ('Step', 0, 'Loss', 0.20759991)
# ('Step', 100, 'Loss', 0.20307425)
# ('Step', 200, 'Loss', 0.21685062)
# ('Step', 300, 'Loss', 0.2052013)
# ('Step', 400, 'Loss', 0.20342052)
# ('Step', 500, 'Loss', 0.20292287)
# ('Step', 600, 'Loss', 0.20439169)
# ('Step', 700, 'Loss', 0.19795641)
# ('Step', 800, 'Loss', 0.20991893)
# ('Step', 900, 'Loss', 0.20228606)
# ('New data, epoch', 68)
# ('Step', 0, 'Loss', 0.20778304)
# ('Step', 100, 'Loss', 0.20705988)
# ('Step', 200, 'Loss', 0.20300381)
# ('Step', 300, 'Loss', 0.20580882)
# ('Step', 400, 'Loss', 0.20970556)
# ('Step', 500, 'Loss', 0.20677668)
# ('Step', 600, 'Loss', 0.20932619)
# ('Step', 700, 'Loss', 0.2091226)
# ('Step', 800, 'Loss', 0.21105972)
# ('Step', 900, 'Loss', 0.20761007)
# ('New data, epoch', 69)
# ('Step', 0, 'Loss', 0.20752212)
# ('Step', 100, 'Loss', 0.21060877)
# ('Step', 200, 'Loss', 0.20501564)
# ('Step', 300, 'Loss', 0.21587564)
# ('Step', 400, 'Loss', 0.20395203)
# ('Step', 500, 'Loss', 0.20876274)
# ('Step', 600, 'Loss', 0.21395607)
# ('Step', 700, 'Loss', 0.20703869)
# ('Step', 800, 'Loss', 0.20984948)
# ('Step', 900, 'Loss', 0.2113343)
# ('New data, epoch', 70)
# ('Step', 0, 'Loss', 0.2058149)
# ('Step', 100, 'Loss', 0.20378026)
# ('Step', 200, 'Loss', 0.20897061)
# ('Step', 300, 'Loss', 0.20889753)
# ('Step', 400, 'Loss', 0.21209323)
# ('Step', 500, 'Loss', 0.21014221)
# ('Step', 600, 'Loss', 0.20780222)
# ('Step', 700, 'Loss', 0.20544623)
# ('Step', 800, 'Loss', 0.21425007)
# ('Step', 900, 'Loss', 0.19384743)
# ('New data, epoch', 71)
# ('Step', 0, 'Loss', 0.21135297)
# ('Step', 100, 'Loss', 0.20759842)
# ('Step', 200, 'Loss', 0.20592989)
# ('Step', 300, 'Loss', 0.2061028)
# ('Step', 400, 'Loss', 0.21415906)
# ('Step', 500, 'Loss', 0.20570414)
# ('Step', 600, 'Loss', 0.21244416)
# ('Step', 700, 'Loss', 0.20702162)
# ('Step', 800, 'Loss', 0.20531791)
# ('Step', 900, 'Loss', 0.20761825)
# ('New data, epoch', 72)
# ('Step', 0, 'Loss', 0.21676284)
# ('Step', 100, 'Loss', 0.21028137)
# ('Step', 200, 'Loss', 0.20726252)
# ('Step', 300, 'Loss', 0.21381587)
# ('Step', 400, 'Loss', 0.20039774)
# ('Step', 500, 'Loss', 0.22014643)
# ('Step', 600, 'Loss', 0.20867214)
# ('Step', 700, 'Loss', 0.2100658)
# ('Step', 800, 'Loss', 0.20757309)
# ('Step', 900, 'Loss', 0.20672703)
# ('New data, epoch', 73)
# ('Step', 0, 'Loss', 0.20658363)
# ('Step', 100, 'Loss', 0.2066499)
# ('Step', 200, 'Loss', 0.2106946)
# ('Step', 300, 'Loss', 0.20857736)
# ('Step', 400, 'Loss', 0.20311464)
# ('Step', 500, 'Loss', 0.20792811)
# ('Step', 600, 'Loss', 0.21012788)
# ('Step', 700, 'Loss', 0.20654346)
# ('Step', 800, 'Loss', 0.21426956)
# ('Step', 900, 'Loss', 0.20878927)
# ('New data, epoch', 74)
# ('Step', 0, 'Loss', 0.20866735)
# ('Step', 100, 'Loss', 0.20534527)
# ('Step', 200, 'Loss', 0.21093927)
# ('Step', 300, 'Loss', 0.20634268)
# ('Step', 400, 'Loss', 0.20728473)
# ('Step', 500, 'Loss', 0.21161208)
# ('Step', 600, 'Loss', 0.21122366)
# ('Step', 700, 'Loss', 0.20950443)
# ('Step', 800, 'Loss', 0.20431988)
# ('Step', 900, 'Loss', 0.20831184)
# ('New data, epoch', 75)
# ('Step', 0, 'Loss', 0.20427288)
# ('Step', 100, 'Loss', 0.2079239)
# ('Step', 200, 'Loss', 0.20801756)
# ('Step', 300, 'Loss', 0.21476863)
# ('Step', 400, 'Loss', 0.20855275)
# ('Step', 500, 'Loss', 0.20786968)
# ('Step', 600, 'Loss', 0.2085811)
# ('Step', 700, 'Loss', 0.21248081)
# ('Step', 800, 'Loss', 0.20709611)
# ('Step', 900, 'Loss', 0.20887899)
# ('New data, epoch', 76)
# ('Step', 0, 'Loss', 0.20664836)
# ('Step', 100, 'Loss', 0.20817514)
# ('Step', 200, 'Loss', 0.20522021)
# ('Step', 300, 'Loss', 0.20879734)
# ('Step', 400, 'Loss', 0.20759793)
# ('Step', 500, 'Loss', 0.21170557)
# ('Step', 600, 'Loss', 0.20591162)
# ('Step', 700, 'Loss', 0.20568341)
# ('Step', 800, 'Loss', 0.21157661)
# ('Step', 900, 'Loss', 0.20513396)
# ('New data, epoch', 77)
# ('Step', 0, 'Loss', 0.20868766)
# ('Step', 100, 'Loss', 0.20527619)
# ('Step', 200, 'Loss', 0.2101364)
# ('Step', 300, 'Loss', 0.21392483)
# ('Step', 400, 'Loss', 0.20606111)
# ('Step', 500, 'Loss', 0.20704781)
# ('Step', 600, 'Loss', 0.20765394)
# ('Step', 700, 'Loss', 0.21083266)
# ('Step', 800, 'Loss', 0.20580187)
# ('Step', 900, 'Loss', 0.21376862)
# ('New data, epoch', 78)
# ('Step', 0, 'Loss', 0.20914887)
# ('Step', 100, 'Loss', 0.20404373)
# ('Step', 200, 'Loss', 0.20862764)
# ('Step', 300, 'Loss', 0.20779288)
# ('Step', 400, 'Loss', 0.20998546)
# ('Step', 500, 'Loss', 0.2101447)
# ('Step', 600, 'Loss', 0.2087305)
# ('Step', 700, 'Loss', 0.20973273)
# ('Step', 800, 'Loss', 0.21027899)
# ('Step', 900, 'Loss', 0.20859709)
# ('New data, epoch', 79)
# ('Step', 0, 'Loss', 0.20952135)
# ('Step', 100, 'Loss', 0.20431036)
# ('Step', 200, 'Loss', 0.20902063)
# ('Step', 300, 'Loss', 0.21832505)
# ('Step', 400, 'Loss', 0.21898577)
# ('Step', 500, 'Loss', 0.21046843)
# ('Step', 600, 'Loss', 0.20549566)
# ('Step', 700, 'Loss', 0.20858963)
# ('Step', 800, 'Loss', 0.21215168)
# ('Step', 900, 'Loss', 0.20816883)
# ('New data, epoch', 80)
# ('Step', 0, 'Loss', 0.2152385)
# ('Step', 100, 'Loss', 0.20430517)
# ('Step', 200, 'Loss', 0.20921332)
# ('Step', 300, 'Loss', 0.20468536)
# ('Step', 400, 'Loss', 0.20797186)
# ('Step', 500, 'Loss', 0.20821382)
# ('Step', 600, 'Loss', 0.20777431)
# ('Step', 700, 'Loss', 0.21280569)
# ('Step', 800, 'Loss', 0.21362121)
# ('Step', 900, 'Loss', 0.20870204)
# ('New data, epoch', 81)
# ('Step', 0, 'Loss', 0.20144272)
# ('Step', 100, 'Loss', 0.20235182)
# ('Step', 200, 'Loss', 0.2091213)
# ('Step', 300, 'Loss', 0.20893981)
# ('Step', 400, 'Loss', 0.20501135)
# ('Step', 500, 'Loss', 0.20798147)
# ('Step', 600, 'Loss', 0.21166559)
# ('Step', 700, 'Loss', 0.21142687)
# ('Step', 800, 'Loss', 0.20772199)
# ('Step', 900, 'Loss', 0.20429917)
# ('New data, epoch', 82)
# ('Step', 0, 'Loss', 0.21168485)
# ('Step', 100, 'Loss', 0.21402337)
# ('Step', 200, 'Loss', 0.20140423)
# ('Step', 300, 'Loss', 0.2101879)
# ('Step', 400, 'Loss', 0.21304044)
# ('Step', 500, 'Loss', 0.20920952)
# ('Step', 600, 'Loss', 0.21055895)
# ('Step', 700, 'Loss', 0.21018609)
# ('Step', 800, 'Loss', 0.20780972)
# ('Step', 900, 'Loss', 0.20500709)
# ('New data, epoch', 83)
# ('Step', 0, 'Loss', 0.20596556)
# ('Step', 100, 'Loss', 0.20380135)
# ('Step', 200, 'Loss', 0.20748664)
# ('Step', 300, 'Loss', 0.20459971)
# ('Step', 400, 'Loss', 0.20627882)
# ('Step', 500, 'Loss', 0.20735838)
# ('Step', 600, 'Loss', 0.20655075)
# ('Step', 700, 'Loss', 0.21178974)
# ('Step', 800, 'Loss', 0.20616202)
# ('Step', 900, 'Loss', 0.20693719)
# ('New data, epoch', 84)
# ('Step', 0, 'Loss', 0.20302849)
# ('Step', 100, 'Loss', 0.21223362)
# ('Step', 200, 'Loss', 0.21103117)
# ('Step', 300, 'Loss', 0.20824432)
# ('Step', 400, 'Loss', 0.21059392)
# ('Step', 500, 'Loss', 0.20632643)
# ('Step', 600, 'Loss', 0.20196594)
# ('Step', 700, 'Loss', 0.20866136)
# ('Step', 800, 'Loss', 0.2083053)
# ('Step', 900, 'Loss', 0.21175458)
# ('New data, epoch', 85)
# ('Step', 0, 'Loss', 0.20315021)
# ('Step', 100, 'Loss', 0.21211183)
# ('Step', 200, 'Loss', 0.20547251)
# ('Step', 300, 'Loss', 0.21023616)
# ('Step', 400, 'Loss', 0.20643204)
# ('Step', 500, 'Loss', 0.20424181)
# ('Step', 600, 'Loss', 0.21095067)
# ('Step', 700, 'Loss', 0.20814642)
# ('Step', 800, 'Loss', 0.20708199)
# ('Step', 900, 'Loss', 0.20916626)
# ('New data, epoch', 86)
# ('Step', 0, 'Loss', 0.21058828)
# ('Step', 100, 'Loss', 0.21345736)
# ('Step', 200, 'Loss', 0.2083617)
# ('Step', 300, 'Loss', 0.21073233)
# ('Step', 400, 'Loss', 0.20862103)
# ('Step', 500, 'Loss', 0.20746233)
# ('Step', 600, 'Loss', 0.21236902)
# ('Step', 700, 'Loss', 0.20912451)
# ('Step', 800, 'Loss', 0.20249172)
# ('Step', 900, 'Loss', 0.21778536)
# ('New data, epoch', 87)
# ('Step', 0, 'Loss', 0.20003727)
# ('Step', 100, 'Loss', 0.20456704)
# ('Step', 200, 'Loss', 0.20873785)
# ('Step', 300, 'Loss', 0.20400208)
# ('Step', 400, 'Loss', 0.20857963)
# ('Step', 500, 'Loss', 0.21089852)
# ('Step', 600, 'Loss', 0.20983158)
# ('Step', 700, 'Loss', 0.21200791)
# ('Step', 800, 'Loss', 0.20740701)
# ('Step', 900, 'Loss', 0.20492154)
# ('New data, epoch', 88)
# ('Step', 0, 'Loss', 0.2099119)
# ('Step', 100, 'Loss', 0.20690347)
# ('Step', 200, 'Loss', 0.20866536)
# ('Step', 300, 'Loss', 0.20349088)
# ('Step', 400, 'Loss', 0.21120726)
# ('Step', 500, 'Loss', 0.20519547)
# ('Step', 600, 'Loss', 0.21786477)
# ('Step', 700, 'Loss', 0.20902905)
# ('Step', 800, 'Loss', 0.20827307)
# ('Step', 900, 'Loss', 0.20868425)
# ('New data, epoch', 89)
# ('Step', 0, 'Loss', 0.21020012)
# ('Step', 100, 'Loss', 0.2067275)
# ('Step', 200, 'Loss', 0.21012183)
# ('Step', 300, 'Loss', 0.19637251)
# ('Step', 400, 'Loss', 0.21165618)
# ('Step', 500, 'Loss', 0.20356825)
# ('Step', 600, 'Loss', 0.20744766)
# ('Step', 700, 'Loss', 0.2019579)
# ('Step', 800, 'Loss', 0.20046753)
# ('Step', 900, 'Loss', 0.20846406)
# ('New data, epoch', 90)
# ('Step', 0, 'Loss', 0.20982426)
# ('Step', 100, 'Loss', 0.20804699)
# ('Step', 200, 'Loss', 0.21090052)
# ('Step', 300, 'Loss', 0.20792525)
# ('Step', 400, 'Loss', 0.21058166)
# ('Step', 500, 'Loss', 0.20774895)
# ('Step', 600, 'Loss', 0.21151358)
# ('Step', 700, 'Loss', 0.21408649)
# ('Step', 800, 'Loss', 0.21063574)
# ('Step', 900, 'Loss', 0.20749392)
# ('New data, epoch', 91)
# ('Step', 0, 'Loss', 0.20811327)
# ('Step', 100, 'Loss', 0.20569159)
# ('Step', 200, 'Loss', 0.21300979)
# ('Step', 300, 'Loss', 0.21315536)
# ('Step', 400, 'Loss', 0.20366915)
# ('Step', 500, 'Loss', 0.21210176)
# ('Step', 600, 'Loss', 0.20998184)
# ('Step', 700, 'Loss', 0.20168449)
# ('Step', 800, 'Loss', 0.20581466)
# ('Step', 900, 'Loss', 0.21177496)
# ('New data, epoch', 92)
# ('Step', 0, 'Loss', 0.21085475)
# ('Step', 100, 'Loss', 0.21173756)
# ('Step', 200, 'Loss', 0.20963798)
# ('Step', 300, 'Loss', 0.21247587)
# ('Step', 400, 'Loss', 0.21026385)
# ('Step', 500, 'Loss', 0.20890631)
# ('Step', 600, 'Loss', 0.20334201)
# ('Step', 700, 'Loss', 0.20743492)
# ('Step', 800, 'Loss', 0.2050105)
# ('Step', 900, 'Loss', 0.20948572)
# ('New data, epoch', 93)
# ('Step', 0, 'Loss', 0.20887695)
# ('Step', 100, 'Loss', 0.20587192)
# ('Step', 200, 'Loss', 0.2155868)
# ('Step', 300, 'Loss', 0.20501962)
# ('Step', 400, 'Loss', 0.20739086)
# ('Step', 500, 'Loss', 0.21924637)
# ('Step', 600, 'Loss', 0.20519508)
# ('Step', 700, 'Loss', 0.20427136)
# ('Step', 800, 'Loss', 0.20600076)
# ('Step', 900, 'Loss', 0.20361091)
# ('New data, epoch', 94)
# ('Step', 0, 'Loss', 0.20958465)
# ('Step', 100, 'Loss', 0.20325832)
# ('Step', 200, 'Loss', 0.20983234)
# ('Step', 300, 'Loss', 0.21105094)
# ('Step', 400, 'Loss', 0.20616776)
# ('Step', 500, 'Loss', 0.2105775)
# ('Step', 600, 'Loss', 0.20847394)
# ('Step', 700, 'Loss', 0.20952468)
# ('Step', 800, 'Loss', 0.2056506)
# ('Step', 900, 'Loss', 0.20454815)
# ('New data, epoch', 95)
# ('Step', 0, 'Loss', 0.20945881)
# ('Step', 100, 'Loss', 0.20396592)
# ('Step', 200, 'Loss', 0.20556176)
# ('Step', 300, 'Loss', 0.20860639)
# ('Step', 400, 'Loss', 0.2036197)
# ('Step', 500, 'Loss', 0.20903994)
# ('Step', 600, 'Loss', 0.2068066)
# ('Step', 700, 'Loss', 0.21194614)
# ('Step', 800, 'Loss', 0.20776141)
# ('Step', 900, 'Loss', 0.2010113)
# ('New data, epoch', 96)
# ('Step', 0, 'Loss', 0.20855704)
# ('Step', 100, 'Loss', 0.21974427)
# ('Step', 200, 'Loss', 0.20781101)
# ('Step', 300, 'Loss', 0.20943126)
# ('Step', 400, 'Loss', 0.20069526)
# ('Step', 500, 'Loss', 0.20961946)
# ('Step', 600, 'Loss', 0.21097325)
# ('Step', 700, 'Loss', 0.20739922)
# ('Step', 800, 'Loss', 0.20925926)
# ('Step', 900, 'Loss', 0.2111962)
# ('New data, epoch', 97)
# ('Step', 0, 'Loss', 0.20727144)
# ('Step', 100, 'Loss', 0.20991828)
# ('Step', 200, 'Loss', 0.20677234)
# ('Step', 300, 'Loss', 0.2034402)
# ('Step', 400, 'Loss', 0.20795828)
# ('Step', 500, 'Loss', 0.2068605)
# ('Step', 600, 'Loss', 0.20709671)
# ('Step', 700, 'Loss', 0.20033735)
# ('Step', 800, 'Loss', 0.2110952)
# ('Step', 900, 'Loss', 0.20097364)
# ('New data, epoch', 98)
# ('Step', 0, 'Loss', 0.209351)
# ('Step', 100, 'Loss', 0.20970568)
# ('Step', 200, 'Loss', 0.21295059)
# ('Step', 300, 'Loss', 0.20852825)
# ('Step', 400, 'Loss', 0.20664126)
# ('Step', 500, 'Loss', 0.20299897)
# ('Step', 600, 'Loss', 0.20473562)
# ('Step', 700, 'Loss', 0.2090006)
# ('Step', 800, 'Loss', 0.20882089)
# ('Step', 900, 'Loss', 0.20883307)
# ('New data, epoch', 99)
# ('Step', 0, 'Loss', 0.20941433)
# ('Step', 100, 'Loss', 0.20900969)
# ('Step', 200, 'Loss', 0.20919594)
# ('Step', 300, 'Loss', 0.20820461)
# ('Step', 400, 'Loss', 0.2086502)
# ('Step', 500, 'Loss', 0.21152376)
# ('Step', 600, 'Loss', 0.20717919)
# ('Step', 700, 'Loss', 0.20966959)
# ('Step', 800, 'Loss', 0.20763868)
# ('Step', 900, 'Loss', 0.21339615)
